# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df2019 = pd.read_csv('2019.csv')
df2018 = pd.read_csv('2018.csv')

# %% [markdown]
# #    2019 verisinin genel özellileri:
#
#
# Ölçüm gerçekleşen ülke sayısı=>

# %%
df2019.shape[0]
# Out:
# 156

# %% [markdown]
# Ülkelerin araştırılan özellikleri=>

# %%
df2019.shape[1]-1
# Out:
# 8

# %% [markdown]
# ### 2019 yılı için dünyanın en mutlu 10 ülkesi

# %%
df2019.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %% [markdown]
# ### Kişibaşı gelirin en yüksek olduğu ülke sıralaması

# %%
df2019.sort_values('GDP per capita',ascending=False)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 28             29                     Qatar  6.374           1.684
# 13             14                Luxembourg  7.090           1.609
# 33             34                 Singapore  6.262           1.572
# 20             21      United Arab Emirates  6.825           1.503
# 50             51                    Kuwait  6.021           1.500
# ..            ...                       ...    ...             ...
# 126           127          Congo (Kinshasa)  4.418           0.094
# 140           141                   Liberia  3.975           0.073
# 144           145                   Burundi  3.775           0.046
# 154           155  Central African Republic  3.083           0.026
# 111           112                   Somalia  4.668           0.000
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 28            1.313                    0.871                         0.555
# ...

# %% [markdown]
# ### Sosyal desteğin en yüksek olduğu ülke sıralaması

# %%
df2019.sort_values('Social support',ascending=False)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 3               4                   Iceland  7.494           1.380
# 0               1                   Finland  7.769           1.340
# 2               3                    Norway  7.554           1.488
# 1               2                   Denmark  7.600           1.383
# 7               8               New Zealand  7.307           1.303
# ..            ...                       ...    ...             ...
# 153           154               Afghanistan  3.203           0.350
# 144           145                   Burundi  3.775           0.046
# 101           102                     Benin  4.883           0.393
# 148           149                     Syria  3.462           0.619
# 154           155  Central African Republic  3.083           0.026
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 3             1.624                    1.026                         0.591
# ...

# %% [markdown]
# ### Sağlığa yaşamda en yüksek ülke sıralaması

# %%
df2019.sort_values('Healthy life expectancy',ascending=False)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 33             34                 Singapore  6.262           1.572
# 75             76                 Hong Kong  5.430           1.438
# 57             58                     Japan  5.886           1.327
# 29             30                     Spain  6.354           1.286
# 5               6               Switzerland  7.480           1.452
# ..            ...                       ...    ...             ...
# 98             99               Ivory Coast  4.944           0.569
# 131           132                      Chad  4.350           0.350
# 143           144                   Lesotho  3.802           0.489
# 154           155  Central African Republic  3.083           0.026
# 134           135                 Swaziland  4.212           0.811
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 33            1.463                    1.141                         0.556
# ...

# %% [markdown]
# ### Seçimlerde özgürlüğe göre en yüksek ülke sıralaması

# %%
df2019.sort_values('Freedom to make life choices',ascending=False)
# Out:
#      Overall rank     Country or region  Score  GDP per capita  \
# 40             41            Uzbekistan  6.174           0.745
# 108           109              Cambodia  4.700           0.574
# 2               3                Norway  7.554           1.488
# 20             21  United Arab Emirates  6.825           1.503
# 0               1               Finland  7.769           1.340
# ..            ...                   ...    ...             ...
# 121           122            Mauritania  4.490           0.570
# 146           147                 Haiti  3.597           0.323
# 148           149                 Syria  3.462           0.619
# 155           156           South Sudan  2.853           0.306
# 153           154           Afghanistan  3.203           0.350
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 40            1.529                    0.756                         0.631
# ...

# %% [markdown]
# ### Gerçekleşen bağışa göre en yüksek ülke sıralaması

# %%
df2019.sort_values('Generosity',ascending=False)
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 130           131           Myanmar  4.360           0.710           1.181
# 91             92         Indonesia  5.192           0.931           1.203
# 146           147             Haiti  3.597           0.323           0.688
# 21             22             Malta  6.726           1.300           1.520
# 120           121             Kenya  4.509           0.512           0.983
# ..            ...               ...    ...             ...             ...
# 41             42         Lithuania  6.149           1.238           1.515
# 88             89           Morocco  5.208           0.801           0.782
# 89             90        Azerbaijan  5.208           1.043           1.147
# 147           148          Botswana  3.488           1.041           1.145
# 81             82            Greece  5.287           1.181           1.156
#
# ...

# %% [markdown]
# ### Yolsuzluk algılarına göre ülke sıralaması(Azdan Çoğa)

# %%
df2019.sort_values('Perceptions of corruption',ascending=False)
# Out:
#      Overall rank       Country or region  Score  GDP per capita  \
# 33             34               Singapore  6.262           1.572
# 151           152                  Rwanda  3.334           0.359
# 1               2                 Denmark  7.600           1.383
# 0               1                 Finland  7.769           1.340
# 7               8             New Zealand  7.307           1.303
# ..            ...                     ...    ...             ...
# 77             78  Bosnia and Herzegovina  5.386           0.945
# 45             46                  Kosovo  6.100           0.882
# 47             48                 Romania  6.070           1.162
# 96             97                Bulgaria  5.011           1.092
# 70             71                 Moldova  5.529           0.685
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 33            1.463                    1.141                         0.556
# ...

# %%
city8n=[]
city8=[]
for i in range(156):
    city8n.append(df2018.loc[i,"Country or region"])
    city8.append(df2018.loc[i,"Country or region"])
    city8.append(df2018.loc[i,"Score"])
city9=[]
for i in range(156):
    city9.append(df2019.loc[i,"Country or region"])
    city9.append(df2019.loc[i,"Score"])

# %%
a=0
fark=[]
fark1=[]
fark2=[]
for i in range(152):
    for x in range(len(city9)):
        if city8n[i]==city9[x]: 
            fark.append(city8n[i])
            fark.append(int(((city9[x+1])*1000)-((city8[(i*2)+1])*1000)))
            fark1.append(int(((city9[x+1])*1000)-((city8[(i*2)+1])*1000)))
            fark2.append(int(((city9[x+1])*1000)-((city8[(i*2)+1])*1000)))
fark1.sort()
fark2.sort(reverse=True)

# %%
sehirler=[]
for i in range(10):
    for x in range(len(fark)):
        if fark2[i]==fark[x]:
            sehirler.append(fark[x-1])

# %%
sehirler
# Out:
# ['Benin',
#  'Guinea',
#  'Liberia',
#  'Niger',
#  'Kosovo',
#  'Honduras',
#  'Ghana',
#  'Israel',
#  'Cyprus',
#  'Portugal']

# %% [markdown]
# Mutluluğu en çok artan ülkeler. Azalan sıralı. Rekor Benin'de.

# %%
sehirler=[]
for i in range(10):
    for x in range(len(fark)):
        if fark1[i]==fark[x]:
            sehirler.append(fark[x-1])

# %%
sehirler
# Out:
# ['Malaysia',
#  'Afghanistan',
#  'Turkmenistan',
#  'Somalia',
#  'Argentina',
#  'Zambia',
#  'Jordan',
#  'Egypt',
#  'Sierra Leone',
#  'Malawi']

# %% [markdown]
# Mutluluğu en çok azalan ülkeler. Azalan sıralı. Rekor Malaysia'da.
